# %% [markdown]
# # EDA for Breast Cancer Data: Preprocess the data for analysis
#
# 1. Understand the data and its shape.
# 2. Check the data types of each column.
# 3. Identify categorical and numerical columns.
# 4. Check for missing values.
# 5. Check descriptive stats
# ##### 6. Group by for classification problem.

# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Load the data

# %%
breast_cancer_data = pd.read_csv('E:\\Learning\\HANDS ON PROJECTS\\PYTHON_EDA\\data.csv')

# %% [markdown]
# ### Explore the data

# %%
breast_cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Remove the unwanted columns.
# ### In this case there is column called 'Unnamed:32' which is full of NAN, you can drop the columns

# %%
breast_cancer_data.drop(columns='Unnamed: 32', axis=1, inplace=True)

# %%
breast_cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Check for shape( number of rows and columns)

# %%
breast_cancer_data.shape
# Out:
# (569, 32)

# %% [markdown]
# ### Check for the missing values and data type

# %%
breast_cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
breast_cancer_data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
### Again, unwanted column was identified, which is "id", so remove that.

# %%
breast_cancer_data.drop(columns='id', axis = 1, inplace = True)

# %%
breast_cancer_data.head(1)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                   0.1189
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Simple aggregation exercise

# %%
breast_cancer_data[breast_cancer_data.columns].agg(['sum', 'count', 'mean', 'std'])
# Out:
#                                                diagnosis  radius_mean  \
# sum    MMMMMMMMMMMMMMMMMMMBBBMMMMMMMMMMMMMMMBMMMMMMMM...  8038.429000
# count                                                569   569.000000
# mean                                                 NaN    14.127292
# std                                                  NaN     3.524049
#
#        texture_mean  perimeter_mean      area_mean  smoothness_mean  \
# sum    10975.810000    52330.380000  372631.900000        54.829000
# count    569.000000      569.000000     569.000000       569.000000
# mean      19.289649       91.969033     654.889104         0.096360
# std        4.301036       24.298981     351.914129         0.014064
#
#        compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# sum           59.370020       50.526811            27.834994     103.081100
# count        569.000000      569.000000           569.000000     569.000000
# ...

# %% [markdown]
# ### Summary stats

# %%
breast_cancer_data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
breast_cancer_data.head(1)
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38           122.8     1001.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1184            0.2776          0.3001               0.1471
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33            184.6
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                   0.1189
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Now we see that the "Diagnosis" column is categorical, and we are doing linear regression
# ### So, convert the categorical column to numerical as in 0 & 1.
#
# #### Check for the various values in the categorical column ~ diagnosis

# %%
breast_cancer_data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# #### Use label encoder package to change the cat to numerical

# %%
label_encode = LabelEncoder()

# %%
label = label_encode.fit_transform(breast_cancer_data.diagnosis)

# %%
breast_cancer_data['target'] = label

# %%
breast_cancer_data.head(20)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M        17.99         10.38          122.80     1001.0
# 1          M        20.57         17.77          132.90     1326.0
# 2          M        19.69         21.25          130.00     1203.0
# 3          M        11.42         20.38           77.58      386.1
# 4          M        20.29         14.34          135.10     1297.0
# 5          M        12.45         15.70           82.57      477.1
# 6          M        18.25         19.98          119.60     1040.0
# 7          M        13.71         20.83           90.20      577.9
# 8          M        13.00         21.82           87.50      519.8
# 9          M        12.46         24.04           83.97      475.9
# 10         M        16.02         23.24          102.70      797.8
# 11         M        15.78         17.89          103.60      781.0
# 12         M        19.17         24.80          132.40     1123.0
# ...

# %%
### Drop the original categorical column,

# %%
breast_cancer_data.drop(columns='diagnosis', axis = 1, inplace= True)

# %%
breast_cancer_data.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
breast_cancer_data.columns
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'target'],
#       dtype='object')

# %%
breast_cancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   perimeter_mean           569 non-null    float64
#  3   area_mean                569 non-null    float64
#  4   smoothness_mean          569 non-null    float64
#  5   compactness_mean         569 non-null    float64
#  6   concavity_mean           569 non-null    float64
#  7   concave points_mean      569 non-null    float64
#  8   symmetry_mean            569 non-null    float64
#  9   fractal_dimension_mean   569 non-null    float64
#  10  radius_se                569 non-null    float64
#  11  texture_se               569 non-null    float64
#  12  perimeter_se             569 non-null    float64
# ...

# %%
breast_cancer_data.target.value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64

# %% [markdown]
# ### Group the data based on the mean

# %%
breast_cancer_data.groupby('target').mean()
# Out:
#         radius_mean  texture_mean  perimeter_mean   area_mean  \
# target
# 0         12.146524     17.914762       78.075406  462.790196
# 1         17.462830     21.604906      115.365377  978.376415
#
#         smoothness_mean  compactness_mean  concavity_mean  \
# target
# 0              0.092478          0.080085        0.046058
# 1              0.102898          0.145188        0.160775
#
#         concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# target                                                              ...
# 0                  0.025717       0.174186                0.062867  ...
# 1                  0.087990       0.192909                0.062680  ...
#
#         radius_worst  texture_worst  perimeter_worst   area_worst  \
# target
# 0          13.379801      23.515070        87.005938   558.899440
# 1          21.134811      29.318208       141.370330  1422.286321
#
#         smoothness_worst  compactness_worst  concavity_worst  \
# target
# ...

# %% [markdown]
# ## Inference: Mean values for Malignant is higher than Beging

# %% [markdown]
# # Summary of EDA
#     1. The data had no missing value.
#     2. All variables are numerical in nature.
#     3. Mean is higher than the median for most of the variables, so the data is right skewed.
#     4. Slight imbalance in the dataset: Beging cases are more than the Malignant cases.
#     5. Mean of most the variables are larger for Malignant cases compared to the Beging cases
